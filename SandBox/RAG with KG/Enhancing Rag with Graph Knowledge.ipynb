# %%
# !pip install langchain openai wikipedia tiktoken neo4j python-dotenv transformers
# !pip install -U sagemaker
# Out:
# Requirement already satisfied: langchain in c:\python312\lib\site-packages (0.0.349)
# Requirement already satisfied: openai in c:\python312\lib\site-packages (1.3.8)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tiktoken in c:\python312\lib\site-packages (0.5.2)
# Collecting neo4j
#   Downloading neo4j-5.15.0.tar.gz (196 kB)
#      ---------------------------------------- 0.0/196.5 kB ? eta -:--:--
#      ------------------------------------- 196.5/196.5 kB 11.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting transformers
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/fc/04/0aad491cd98b09236c54ab849863ee85421eeda5138bbf9d33ecc594652b/transformers-4.36.1-py3-none-any.whl.metadata
#   Downloading transformers-4.36.1-py3-none-any.whl.metadata (126 kB)
#      ---------------------------------------- 0.0/126.8 kB ? eta -:--:--
#      ---------------------------------------- 126.8/126.8 kB ? eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in c:\python312\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\python312\lib\site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\python312\lib\site-packages (from langchain) (3.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\python312\lib\site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\python312\lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.1 in c:\python312\lib\site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langchain-core<0.1,>=0.0.13 in c:\python312\lib\site-packages (from langchain) (0.0.13)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in c:\python312\lib\site-packages (from langchain) (0.0.69)
# Requirement already satisfied: numpy<2,>=1 in c:\python312\lib\site-packages (from langchain) (1.26.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\python312\lib\site-packages (from langchain) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in c:\python312\lib\site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\python312\lib\site-packages (from langchain) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\python312\lib\site-packages (from openai) (4.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\python312\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\python312\lib\site-packages (from openai) (0.25.2)
# Requirement already satisfied: sniffio in c:\python312\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\python312\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\python312\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: beautifulsoup4 in c:\python312\lib\site-packages (from wikipedia) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\python312\lib\site-packages (from tiktoken) (2023.10.3)
# Collecting pytz (from neo4j)
#   Obtaining dependency information for pytz from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting filelock (from transformers)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Obtaining dependency information for huggingface-hub<1.0,>=0.19.3 from https://files.pythonhosted.org/packages/05/09/1945ca6ba3ad8ad6e2872ba682ce8d68c5e63c8e55458ed8ab4885709f1d/huggingface_hub-0.19.4-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in c:\python312\lib\site-packages (from transformers) (23.2)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.0.tar.gz (318 kB)
#      ---------------------------------------- 0.0/318.5 kB ? eta -:--:--
#      ------------------------------------- 318.5/318.5 kB 20.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#
#   Cargo, the Rust package manager, is not installed or is not on PATH.
#   This package requires Rust and Cargo to compile extensions. Install it through
#   the system's package manager or via https://rustup.rs/
#
#   Checking for Rust toolchain....
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting sagemakerNote: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'C:\\Python312\\Scripts\\ppserver'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for sagemaker from https://files.pythonhosted.org/packages/6b/2e/5a212380364960a209f8397be1f382e02d9078175435cc393e70af39d05a/sagemaker-2.200.0-py2.py3-none-any.whl.metadata
#   Downloading sagemaker-2.200.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: attrs<24,>=23.1.0 in c:\python312\lib\site-packages (from sagemaker) (23.1.0)
# Collecting boto3<2.0,>=1.33.3 (from sagemaker)
#   Obtaining dependency information for boto3<2.0,>=1.33.3 from https://files.pythonhosted.org/packages/b7/53/566ed4ae3207fe012c8d57b30e95f2a89b90e9f2efa03408cdfe0773e318/boto3-1.34.0-py3-none-any.whl.metadata
#   Downloading boto3-1.34.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpickle==2.2.1 (from sagemaker)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting google-pasta (from sagemaker)
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#      ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.9.0 in c:\python312\lib\site-packages (from sagemaker) (1.26.2)
# Collecting protobuf<5.0,>=3.12 (from sagemaker)
#   Obtaining dependency information for protobuf<5.0,>=3.12 from https://files.pythonhosted.org/packages/fe/6b/7f177e8d6fe4caa14f4065433af9f879d4fab84f0d17dcba7b407f6bd808/protobuf-4.25.1-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.1-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Obtaining dependency information for importlib-metadata<7.0,>=1.4.0 from https://files.pythonhosted.org/packages/59/9b/ecce94952ab5ea74c31dcf9ccf78ccd484eebebef06019bf8cb579ab4519/importlib_metadata-6.11.0-py3-none-any.whl.metadata
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=20.0 in c:\python312\lib\site-packages (from sagemaker) (23.2)
# Collecting pandas (from sagemaker)
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting pathos (from sagemaker)
#   Obtaining dependency information for pathos from https://files.pythonhosted.org/packages/d8/08/ac94fa6f9eefe32963b8a54e573dab0dbc0d3df24fd34924bd9ce7eab7c4/pathos-0.3.1-py3-none-any.whl.metadata
#   Downloading pathos-0.3.1-py3-none-any.whl.metadata (11 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: PyYAML~=6.0 in c:\python312\lib\site-packages (from sagemaker) (6.0.1)
# Requirement already satisfied: jsonschema in c:\python312\lib\site-packages (from sagemaker) (4.20.0)
# Requirement already satisfied: platformdirs in c:\python312\lib\site-packages (from sagemaker) (4.1.0)
# Collecting tblib==1.7.0 (from sagemaker)
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting urllib3<1.27 (from sagemaker)
#   Obtaining dependency information for urllib3<1.27 from https://files.pythonhosted.org/packages/b0/53/aa91e163dcfd1e5b82d8a890ecf13314e3e149c05270cc644581f77f17fd/urllib3-1.26.18-py2.py3-none-any.whl.metadata
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB ? eta 0:00:00
# Collecting uvicorn==0.22.0 (from sagemaker)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Collecting fastapi==0.95.2 (from sagemaker)
#   Obtaining dependency information for fastapi==0.95.2 from https://files.pythonhosted.org/packages/4e/1a/04887c641b67e6649bde845b9a631f73a7abfbe3afda83957e09b95d88eb/fastapi-0.95.2-py3-none-any.whl.metadata
#   Downloading fastapi-0.95.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in c:\python312\lib\site-packages (from sagemaker) (2.31.0)
# Collecting docker (from sagemaker)
#   Obtaining dependency information for docker from https://files.pythonhosted.org/packages/18/bd/9706c10bb12e05043ef138dc8d412cfd17f29c8df0fb28ad71c96a98785d/docker-7.0.0-py3-none-any.whl.metadata
#   Downloading docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from sagemaker) (4.66.1)
# Requirement already satisfied: psutil in c:\python312\lib\site-packages (from sagemaker) (5.9.6)
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 (from fastapi==0.95.2->sagemaker)
#   Obtaining dependency information for pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 from https://files.pythonhosted.org/packages/39/9f/ab6d19c5d3fccc1e3e0d835ac773031388802b31d93937daf878465c2ecf/pydantic-1.10.13-py3-none-any.whl.metadata
#   Downloading pydantic-1.10.13-py3-none-any.whl.metadata (149 kB)
#      ---------------------------------------- 0.0/149.6 kB ? eta -:--:--
#      ---------------------------------------- 149.6/149.6 kB ? eta 0:00:00
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.95.2->sagemaker)
#   Obtaining dependency information for starlette<0.28.0,>=0.27.0 from https://files.pythonhosted.org/packages/58/f8/e2cca22387965584a409795913b774235752be4176d276714e15e1a58884/starlette-0.27.0-py3-none-any.whl.metadata
#   Downloading starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting click>=7.0 (from uvicorn==0.22.0->sagemaker)
#   Obtaining dependency information for click>=7.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: h11>=0.8 in c:\python312\lib\site-packages (from uvicorn==0.22.0->sagemaker) (0.14.0)
# Collecting botocore<1.35.0,>=1.34.0 (from boto3<2.0,>=1.33.3->sagemaker)
#   Obtaining dependency information for botocore<1.35.0,>=1.34.0 from https://files.pythonhosted.org/packages/08/01/04158480f625843e8cd658778e4f4795409c2fbe7632a69dbb88d415108c/botocore-1.34.0-py3-none-any.whl.metadata
#   Downloading botocore-1.34.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.33.3->sagemaker)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.10.0,>=0.9.0 (from boto3<2.0,>=1.33.3->sagemaker)
#   Obtaining dependency information for s3transfer<0.10.0,>=0.9.0 from https://files.pythonhosted.org/packages/fd/fb/46eda754e80fa2efd82981e37cd75cabbecef71df63843e6e94e12fae9db/s3transfer-0.9.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.9.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=1.4.0->sagemaker)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pywin32>=304 in c:\python312\lib\site-packages (from docker->sagemaker) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests->sagemaker) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests->sagemaker) (2023.11.17)
# Requirement already satisfied: six in c:\python312\lib\site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\python312\lib\site-packages (from jsonschema->sagemaker) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\python312\lib\site-packages (from jsonschema->sagemaker) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\python312\lib\site-packages (from jsonschema->sagemaker) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas->sagemaker) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->sagemaker)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas->sagemaker)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 20.7 MB/s eta 0:00:00
# Collecting ppft>=1.7.6.7 (from pathos->sagemaker)
#   Obtaining dependency information for ppft>=1.7.6.7 from https://files.pythonhosted.org/packages/f0/f8/0a493dfdf73edbfe58cae1323aec72d0152f463c7a351bd285e9d500985c/ppft-1.7.6.7-py3-none-any.whl.metadata
#   Downloading ppft-1.7.6.7-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.7 (from pathos->sagemaker)
#   Obtaining dependency information for dill>=0.3.7 from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting pox>=0.3.3 (from pathos->sagemaker)
#   Obtaining dependency information for pox>=0.3.3 from https://files.pythonhosted.org/packages/17/c7/ef7e37e5a895f5de068b408a52bee0710b1092574b6b4ab247a767e9fbd5/pox-0.3.3-py3-none-any.whl.metadata
#   Downloading pox-0.3.3-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.15 (from pathos->sagemaker)
#   Obtaining dependency information for multiprocess>=0.70.15 from https://files.pythonhosted.org/packages/e7/41/96ac938770ba6e7d5ae1d8c9cafebac54b413549042c6260f0d0a6ec6622/multiprocess-0.70.15-py311-none-any.whl.metadata
#   Downloading multiprocess-0.70.15-py311-none-any.whl.metadata (7.2 kB)
# Collecting contextlib2>=0.5.5 (from schema->sagemaker)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from tqdm->sagemaker) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\python312\lib\site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi==0.95.2->sagemaker) (4.9.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\python312\lib\site-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.95.2->sagemaker) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\python312\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.95.2->sagemaker) (1.3.0)
# Downloading sagemaker-2.200.0-py2.py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------------------- ---- 1.2/1.4 MB 25.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 21.7 MB/s eta 0:00:00
# Downloading fastapi-0.95.2-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Downloading boto3-1.34.0-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    ---------------------------------------- 139.3/139.3 kB 8.1 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading protobuf-4.25.1-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 13.0 MB/s eta 0:00:00
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.8 kB ? eta -:--:--
#    ---------------------------------------- 143.8/143.8 kB 8.3 MB/s eta 0:00:00
# Downloading docker-7.0.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.6 kB ? eta -:--:--
#    ---------------------------------------- 147.6/147.6 kB 9.2 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp312-cp312-win_amd64.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.2/10.5 MB 25.9 MB/s eta 0:00:01
#    --------- ------------------------------ 2.5/10.5 MB 26.0 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/10.5 MB 26.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.5 MB 25.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.5 MB 25.8 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.5 MB 26.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.5 MB 26.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.7/10.5 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.5 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 24.2 MB/s eta 0:00:00
# Downloading pathos-0.3.1-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.1 kB ? eta -:--:--
#    ---------------------------------------- 82.1/82.1 kB 4.8 MB/s eta 0:00:00
# Downloading botocore-1.34.0-py3-none-any.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.2/11.8 MB 24.6 MB/s eta 0:00:01
#    ------- -------------------------------- 2.4/11.8 MB 24.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.6/11.8 MB 25.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.8/11.8 MB 25.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.8 MB 25.7 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/11.8 MB 25.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.5/11.8 MB 25.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/11.8 MB 25.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.9/11.8 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------  11.8/11.8 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 23.4 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB ? eta 0:00:00
# Downloading multiprocess-0.70.15-py311-none-any.whl (135 kB)
#    ---------------------------------------- 0.0/135.4 kB ? eta -:--:--
#    ---------------------------------------- 135.4/135.4 kB ? eta 0:00:00
# Downloading pox-0.3.3-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.7-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB ? eta 0:00:00
# Downloading pydantic-1.10.13-py3-none-any.whl (158 kB)
#    ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#    ---------------------------------------- 158.6/158.6 kB ? eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ---------------------------------------- 0.0/502.5 kB ? eta -:--:--
#    --------------------------------------- 502.5/502.5 kB 30.8 MB/s eta 0:00:00
# Downloading s3transfer-0.9.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#    ---------------------------------------- 82.0/82.0 kB 4.8 MB/s eta 0:00:00
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/67.0 kB ? eta -:--:--
#    ---------------------------------------- 67.0/67.0 kB 3.5 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: pytz, zipp, urllib3, tzdata, tblib, smdebug-rulesconfig, pydantic, protobuf, ppft, pox, jmespath, google-pasta, dill, contextlib2, cloudpickle, click, uvicorn, starlette, schema, pandas, multiprocess, importlib-metadata, botocore, s3transfer, pathos, fastapi, docker, boto3, sagemaker
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.2
#     Uninstalling pydantic-2.5.2:
#       Successfully uninstalled pydantic-2.5.2
